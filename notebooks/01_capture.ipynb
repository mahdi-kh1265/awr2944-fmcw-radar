# %% [markdown]
# # AWR2944 Direct Capture (Phase I)
#
# This notebook runs an end-to-end capture on the AWR2944 using the DCA1000 EVM.
# It uses direct UDP and UART communication, completely bypassing mmWave Studio.

# %%
from awr2944_dca.lab import RadarProject

# Open the project in the current working directory
lab = RadarProject.open_here()

# Run the smoke_v1 capture with default guard frames
result = lab.capture.run_smoke(frames=9, guard_frames=1)

# Print the summary
result.summary()

# Launch the standalone MATLAB viewer
result.open_viewer()
