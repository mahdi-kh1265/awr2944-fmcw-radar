# %% [markdown]
# # Compare Layouts Demo
#
# This notebook demonstrates how to invoke the layout comparison tool programmatically.

# %%
from awr2944_dca.api.experiment import Experiment

exp = Experiment.init(name="notebook_layout_compare", preset="first-capture")

# Note: exp.compare_layouts() is currently a placeholder for the API layer.
# You can run `awr compare-layouts adc_data.bin` from the CLI instead for full functionality.
try:
    exp.compare_layouts()
    print("Layout comparison executed.")
except NotImplementedError:
    print("compare_layouts() API wrapper not fully implemented yet.")
