# %% [markdown]
# # Viewer Launcher
#
# This notebook launches the standalone MATLAB viewer for a given capture.

# %%
from awr2944_dca.lab import RadarProject

# Open the project
lab = RadarProject.open_here()

# List available captures
for c in lab.captures():
    print(f"[{c.capture_id}] {c.status().get('status', 'Unknown')}")

# %%
# Select a capture to view
capture_id = "capture_XXXXXXXX" # Replace with actual capture ID

capture = lab.get_capture(capture_id)

# Ensure viewer_payload.mat is generated and launch the standalone viewer
print("Exporting viewer payload and launching UI...")
capture.open_viewer()

# %% [markdown]
# ## Developer DSP Workbench
# For older Plotly-based viewer notebooks used for algorithm development, see the `03b_plotly_developer_viewer.ipynb` notebook.
